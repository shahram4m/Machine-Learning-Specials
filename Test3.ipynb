# %%
matrix = ['Tsi', 'h%x', 'i #', 'sM ', '$a ', '#t%', 'ir!']

#!/bin/python3
import math
import os
import random
import re
import sys
# first_multiple_input = input().rstrip().split()
# n = int(first_multiple_input[0])
# m = int(first_multiple_input[1])
# matrix = []

# for _ in range(n):
#     matrix_item = input()
#     matrix.append(matrix_item)

print(matrix)
# for index,item in enumerate(matrix):
#     print(item)
result = str()
alpha = ['T', 't', 'h','H','i','I', 'S', 's', 'M','a','r','x','A','R','X' ]
matrix = ['Tsi', 'h%x', 'i #', 'sM ', '$a ', '#t%', 'ir!']
transposed_array = [[row[i] for row in matrix] for i in range(len(matrix[0]))]
print(transposed_array)

for index, item in enumerate(transposed_array):
    for sub in list(item): 
        result = result + sub + str(sub in alpha)
        # result.append((sub, sub in alpha))
        # print(sub)
first_splited_result = result.split("False")
first_result = str()

print(first_splited_result)
    



filtered_lst = filter(lambda x: x[1] in True, result)

print(result)
print(filtered_lst)
# Out:
# ['Tsi', 'h%x', 'i #', 'sM ', '$a ', '#t%', 'ir!']
# [['T', 'h', 'i', 's', '$', '#', 'i'], ['s', '%', ' ', 'M', 'a', 't', 'r'], ['i', 'x', '#', ' ', ' ', '%', '!']]
# ['TTruehTrueiTruesTrue$', '#', 'iTruesTrue%', ' ', 'MTrueaTruetTruerTrueiTruexTrue#', ' ', ' ', '%', '!', '']
# TTruehTrueiTruesTrue$False#FalseiTruesTrue%False FalseMTrueaTruetTruerTrueiTruexTrue#False False False%False!False
# ...

# %%
# Create a sample 2D list (matrix)
# matrix = [[1, 2, 3],
#           [4, 5, 6],
#           [7, 8, 9]]


matrix = ['Tsi', 'h%x', 'i #', 'sM ', '$a ', '#t%', 'ir!']
transposed_array = [[row[i] for row in matrix] for i in range(len(matrix[0]))]
print(transposed_array)



# Extract the second column from the matrix
column_index = 1
result = []
# for column_index, item in matrix:
#     column = [row[column_index] for row in matrix]

column = [row[column_index] for row in matrix]
# Convert the column into a row list
row = [column]

print("Column:")
print(column)
print("\nRow:")
print(row)
# Out:
# [['T', 'h', 'i', 's', '$', '#', 'i'], ['s', '%', ' ', 'M', 'a', 't', 'r'], ['i', 'x', '#', ' ', ' ', '%', '!']]
# Column:
# [2, 5, 8]
#
# Row:
# [[2, 5, 8]]

# %%
matrix = ['Tsi', 'h%x', 'i #', 'sM ', '$a ', '#t%', 'ir!']

#!/bin/python3
import math
import os
import random
import re
import sys
# first_multiple_input = input().rstrip().split()
# n = int(first_multiple_input[0])
# m = int(first_multiple_input[1])
# matrix = []

# for _ in range(n):
#     matrix_item = input()
#     matrix.append(matrix_item)

print(matrix)
# for index,item in enumerate(matrix):
#     print(item)
result0 = str()
result =[]
alpha = ['T', 't', 'h','H','i','I', 'S', 's', 'M','a','r','x','A','R','X' ]
matrix = ['Tsi', 'h%x', 'i #', 'sM ', '$a ', '#t%', 'ir!']
transposed_array = [[row[i] for row in matrix] for i in range(len(matrix[0]))]
print(transposed_array)

for index, item in enumerate(transposed_array):
    for sub in list(item): 
        #result0 = result + sub + str(sub in alpha)
        result.append((sub, sub in alpha))
        # print(sub)

first_splited_result = result0.split("False")
first_result = str()
print(first_splited_result)
    



filtered_lst = list(filter(lambda x: x[1] == True, result))
                #list(filter(lambda x : x ==1 ,data))

for i in filtered_lst:
    print(i[0])


# print(result)
# print(filtered_lst)
# Out:
# ['Tsi', 'h%x', 'i #', 'sM ', '$a ', '#t%', 'ir!']
# [['T', 'h', 'i', 's', '$', '#', 'i'], ['s', '%', ' ', 'M', 'a', 't', 'r'], ['i', 'x', '#', ' ', ' ', '%', '!']]
# ['']
# T
# h
# i
# s
# i
# s
# M
# a
# t
# r
# i
# x

# %%
matrix = ['Tsi', 'h%x', 'i #', 'sM ', '$a ', '#t%', 'ir!']
#This is Matrix#  %!

#!/bin/python3
import math
import os
import random
import re
import sys
# first_multiple_input = input().rstrip().split()
# n = int(first_multiple_input[0])
# m = int(first_multiple_input[1])
# matrix = []

# for _ in range(n):
#     matrix_item = input()
#     matrix.append(matrix_item)

#print(matrix)
# for index,item in enumerate(matrix):
#     print(item)
result0 = str()
result =[]
alpha = ['T', 't', 'h','H','i','I', 'S', 's', 'M','a','r','x','A','R','X' ]
matrix = ['Tsi', 'h%x', 'i #', 'sM ', '$a ', '#t%', 'ir!']
transposed_array = [[row[i] for row in matrix] for i in range(len(matrix[0]))]
letters = str()
signs = str()

for a in transposed_array:
    for b in a:
        while b.isalpha():
            letter = letter+b
        while b.isspace():
            letter = letter+b
        sign = sign+b
print(letters, signs)
#print(transposed_array)
for index, item in enumerate(transposed_array):
    for sub in list(item): 
        result0 = result0 + sub
        result.append((sub, sub in alpha))
        # print(sub)

print(result0)
print(result)
#result0 = list(result0)
print(result0.rfind('x'))
110000
#max = max(result0, key=lambda x: x in alpha)
#print(max)

#filtered_lst = list(filter(lambda x: x[1] == True, result))



# first_splited_result = result0.split("False")
# first_result = str()
# print(first_splited_result)


# filtered_lst = list(filter(lambda x: x[1] == True, result))
#                 #list(filter(lambda x : x ==1 ,data))

# for i in filtered_lst:
#     print(i[0])

# print(result)
# print(filtered_lst)
# Out:
# ['Tsi', 'h%x', 'i #', 'sM ', '$a ', '#t%', 'ir!']
# [['T', 'h', 'i', 's', '$', '#', 'i'], ['s', '%', ' ', 'M', 'a', 't', 'r'], ['i', 'x', '#', ' ', ' ', '%', '!']]
# This$#is% Matrix#  %!
# [('T', True), ('h', True), ('i', True), ('s', True), ('$', False), ('#', False), ('i', True), ('s', True), ('%', False), (' ', False), ('M', True), ('a', True), ('t', True), ('r', True), ('i', True), ('x', True), ('#', False), (' ', False), (' ', False), ('%', False), ('!', False)]
# 15

# %%
matrix = ['Tsi', 'h%x', 'i #', 'sM ', '$a ', '#t%', 'ir!']

#This$#is% Matrix#  %!
#This is Matrix#  %!

#!/bin/python3
import math
import os
import random
import re
import sys
# first_multiple_input = input().rstrip().split()
# n = int(first_multiple_input[0])
# m = int(first_multiple_input[1])
# matrix = []

# for _ in range(n):
#     matrix_item = input()
#     matrix.append(matrix_item)

#print(matrix)
# for index,item in enumerate(matrix):
#     print(item)
result0 = str()
result =[]
alpha = ['T', 't', 'h','H','i','I', 'S', 's', 'M','a','r','x','A','R','X' ]
matrix = ['Tsi', 'h%x', 'i #', 'sM ', '$a ', '#t%', 'ir!']
transposed_array = [[row[i] for row in matrix] for i in range(len(matrix[0]))]
print(transposed_array)
letters = str()
sign = str()
sign_count = 0
for a in transposed_array:
    for b in a:
        while b.isalpha():
            sign_count = 0
            letters = letters+b
            break
        while b.isspace():
            letters = letters+b
            while sign_count<1:
                sign_count +=1
                break
            break
        while not b.isalpha() and not b.isspace():
            sign = sign+b
            while sign_count<1:
                sign_count +=1
                letters += " "
                break
            break
print(letters+sign)
# Out:
# [['T', 'h', 'i', 's', '$', '#', 'i'], ['s', '%', ' ', 'M', 'a', 't', 'r'], ['i', 'x', '#', ' ', ' ', '%', '!']]
# This is  Matrix   $#%#%!

# %%
n = 6
arr=[-4,3,-9,0,4,1]
arr2=[1,2,3,-1,-2,-3,0,0]

print(len(list(filter(lambda x: x == 0 , arr)))/n)
print(len(list(filter(lambda x: x > 0 , arr)))/n)
print(len(list(filter(lambda x: x < 0 , arr)))/n)


# print(list(filter(lambda x: x < 0 , arr)))


# print(all(x > 0 for x in arr))
# print(all(x < 0 for x in arr))
# print(all(x == 0 for x in arr))


# print(len(list(all(x > 0 for x in arr)))/n)
# print(len(list(all(x < 0 for x in arr)))/n)
# print(len(list(all(x == 0 for x in arr)))/n)

# for index , item in enumerate(arr):
#     print(len(list(filter(lambda x: x == item , arr)))/n)
# Out:
# 0.16666666666666666
# 0.5
# 0.3333333333333333

# %%
matrix = ['Tsi', 'h%x', 'i #', 'sM ', '$a ', '#t%', 'ir!']

#This$#is% Matrix#  %!
#This is Matrix#  %!

#!/bin/python3
import math
import os
import random
import re
import sys
# first_multiple_input = input().rstrip().split()
# n = int(first_multiple_input[0])
# m = int(first_multiple_input[1])
# matrix = []

# for _ in range(n):
#     matrix_item = input()
#     matrix.append(matrix_item)

#print(matrix)
# for index,item in enumerate(matrix):
#     print(item)
#result0 = str()
result =[]
alpha = ['T', 't', 'h','H','i','I', 'S', 's', 'M','a','r','x','A','R','X' ]
matrix = ['Tsi', 'h%x', 'i #', 'sM ', '$a ', '#t%', 'ir!']
alpha = ''
space = 0
sign = 0
transposed_array = [[row[i] for row in matrix] for i in range(len(matrix[0]))]
print(transposed_array)
#for str in transposed_array:
for index, str in enumerate(transposed_array):
     for substr in str:   
        while substr.isalpha(): #or (str[index-1].isalpha() and str[index+1].isalpha()):
             alpha = alpha + substr
             break
        while substr.isspace():            
             space = space + 1
             break
        while not substr.isspace() and not substr.isalpha():
            sign = sign + 1
            break
        while not substr.isspace() and not substr.isalpha() and sign > 1 :
            sign = sign - 1
            alpha = alpha + ' '
            break
        while not substr.isspace() and not substr.isalpha() and sign == 1:
            #sign = sign - 1
            alpha = alpha + substr
            break
            
print(alpha)        
#This$# is%  Matrix#   % !

# %%
matrix = ['Tsi', 'h%x', 'i #', 'sM ', '$a ', '#t%', 'ir!']

#This$#is% Matrix#  %!
#This is Matrix#  %!

#!/bin/python3
import math
import os
import random
import re
import sys
result =[]
alpha = ['T', 't', 'h','H','i','I', 'S', 's', 'M','a','r','x','A','R','X' ]
matrix = ['Tsi', 'h%x', 'i #', 'sM ', '$a ', '#t%', 'ir!']
alpha = ''
space = 0
sign = 0
result = ''
transposed_array = [[row[i] for row in matrix] for i in range(len(matrix[0]))]
print(transposed_array)
#for str in transposed_array:
for index, str in enumerate(transposed_array):
    for substr in str:   
        result = result + substr
print(result)  
res_aplha = []
res_sign = []

for index, substr in enumerate(result):
        while substr.isalpha():
             alpha = alpha + substr             
             break
        res.append(alpha)
        while substr.isspace():            
             space = space + 1
             break
        while not substr.isspace() and not substr.isalpha():
            sign = sign + 1
            break
        while not substr.isspace() and not substr.isalpha() and sign > 1:
            sign = sign - 1
            alpha = alpha + ' '
            break
        # while not substr.isspace() and not substr.isalpha() and sign == 1:
        #     #sign = sign - 1
        #     alpha = alpha + substr
        #     break
                
            
print(alpha)
# Out:
# [['T', 'h', 'i', 's', '$', '#', 'i'], ['s', '%', ' ', 'M', 'a', 't', 'r'], ['i', 'x', '#', ' ', ' ', '%', '!']]
# This$#is% Matrix#  %!
# This is Matrix

# %%
#matrix = ['Tsi', 'h%x', 'i #', 'sM ', '$a ', '#t%', 'ir!']
matrix = ['# i#',' @#U']
   
#This$#is% Matrix#  %!
#This is Matrix#  %!

#!/bin/python3
import math
import os
import random
import re
import sys
result =[]
# alpha = ['T', 't', 'h','H','i','I', 'S', 's', 'M','a','r','x','A','R','X' ]
alpha = ''
space = 0
sign = 0
result = ''
space_sign=''
transposed_array = [[row[i] for row in matrix] for i in range(len(matrix[0]))]
res_aplha = []
res_sign = []
alphalist = []

res_aplha2 = []
res_sign2 = []
res = []


for index, str in enumerate(transposed_array):
    for substr in str:  
        while substr.isalpha():
             alpha = alpha + substr             
             break
        res.append(alpha)
        while substr.isspace():            
             space = space + 1
             break
        while not substr.isspace() and not substr.isalpha():
            sign = sign + 1
            break
        while not substr.isspace() and not substr.isalpha() and sign > 1:
            sign = sign - 1
            alpha = alpha + ' '
            break

for index, str in enumerate(transposed_array):
    for substr in str:   
        result = result + substr
alpha1 = ''  
for index, substr in enumerate(result):
        #print(substr)
        while substr.isalpha():
             alpha1 = alpha1 + substr             
             break        
        while not substr.isalpha():            
            res_aplha.append(alpha)
            havealpha = True
            checkalpha = False
            for s in result[index+1:]:                
                while s.isalpha():
                    # print(s)
                    checkalpha = True
                    break
            while not checkalpha:
                space_sign = space_sign + substr 
                res_aplha2.append(substr)
                break            
            alpha1 = ''
            break   

print(alpha.strip() + space_sign)
# Out:
# i  U

# %%
matrix = ['Tsi', 'h%x', 'i #', 'sM ', '$a ', '#t%', 'ir!']
# matrix = ['2 4','# i#',' @#U']
matrix0 = ['# i#',' @#U']

#This$#is% Matrix#  %!
#This is Matrix#  %!

#!/bin/python3
import math
import os
import random
import re
import sys
result =[]
# alpha = ['T', 't', 'h','H','i','I', 'S', 's', 'M','a','r','x','A','R','X' ]
# matrix = ['Tsi', 'h%x', 'i #', 'sM ', '$a ', '#t%', 'ir!']

alpha = ''
space = 0
sign = 0
result = ''
space_sign=''
res_aplha = []
res_sign = []
alphalist = []
res_aplha2 = []
res_sign2 = []

transposed_array = [[row[i] for row in matrix] for i in range(len(matrix[0]))]
for index, str in enumerate(transposed_array):
    for substr in str:   
        result = result + substr
        
for index, substr in enumerate(result):
        while substr.isalpha():
             alpha = alpha + substr             
             break        
        while not substr.isalpha():            
            while len(alpha)>=1:
                res_aplha.append(alpha)
                break
            havealpha = True
            checkalpha = False
            for s in result[index+1:]:                
                while s.isalpha():
                    checkalpha = True
                    break
            while not checkalpha:
                space_sign = space_sign + substr 
                res_aplha2.append(substr)
                break            
            alpha = ''
            break   
            
strEnd = ''
for item in res_aplha:
    while len(item) > 1:
        strEnd = strEnd+' '+item
        break
       
print(strEnd+space_sign)
# Out:
#  This is Matrix#  %!

# %%
# input_str='552523'
# input_str='121426'
# input_str='523563' 
input_str='552523'
#input_str='110000'
split_parts = []
result = []

for i in range(len(input_str) - 2):
    split_parts.append([int(input_str[i]), int(input_str[i + 1]), int(input_str[i + 2])])
print(split_parts)

checkloop= True
for index, item in enumerate(split_parts):
    print(item[0],item[1])
    while item[0] == item[1]: #and checkloop:
        checkloop  = False
        result.append(1)
        break
print(len(result))


# length = len(input)
# index = 5
# #print(input[-1*(length-index)])

# for index , item in enumerate(input):  
#     print(input[index:3])
# checkloop= True
# for index , item in enumerate(input):        
#         print(index, index + 2, item)
#         while len(input) < index + 2:
#             checkloop  = False
#             break
#         while checkloop and item == input[index+2]:
#             print(item)
#                 # print(input.rfind(item))
#             break
# Out:
# [[5, 5, 2], [5, 2, 5], [2, 5, 2], [5, 2, 3]]
# 5 5
# 5 2
# 2 5
# 5 2
# False
# ['True']

# %%
import re
def regex_integer_in_range():
    pattern = r'(?<!\d)([1-9]\d{5})(?!\d)'  # Matches numbers greater than 100,000 and less than 999,999
    return re.compile(pattern)

121426 # Here, 1 is an alternating repetitive digit.
523563 # Here, NO digit is an alternating repetitive digit.
552523 # Here, both 2 and 5 are alternating repetitive digits.

def regex_alternating_repetitive_digit_pair(input_str):
    split_parts = []
    result = []
    finalresult = False
    pattern = 'No match'
    for i in range(len(input_str) - 2):
        split_parts.append([int(input_str[i]), int(input_str[i + 1]), int(input_str[i + 2])])
    
    for index, item in enumerate(split_parts):
        while item[0] == item[1]:
            result.append(1)
            break

    while len(result) < 2:
        finalresult = True
        pattern = r'(\d)\1'
        break

    print(pattern)
    #pattern = r'(\d)\1' finalresult
    return re.compile(pattern)


# Testing:
#P = '523563'
#P='552523'
#P='121426'
P='523563' 
#P='552523'
# P='110000'

# (?=(\d)\d\1)

#regex = regex_alternating_repetitive_digit_pair(input_str)
#print(len(re.findall(regex, input_str)) < 2)

regex_integer_in_range = r"".format(regex_integer_in_range())	# Do not delete 'r'.
regex_alternating_repetitive_digit_pair = r"".format(regex_alternating_repetitive_digit_pair(P))	# Do not delete 'r'.

# print (bool(re.match(regex_integer_in_range, P)) and len(re.findall(regex_alternating_repetitive_digit_pair, P)) < 2)
print(bool(re.match(regex_integer_in_range, P)) )
print(len(re.findall(regex_alternating_repetitive_digit_pair, P)) < 2)
# Out:
# (\d)\1
# True
# False

# %%
# import collections
7 867
7 6429964 4173738 9941618 2744666 5392018 5813128 9452095
7 6517823 4135421 6418713 9924958 9370532 7940650 2027017
7 1506500 3460933 1550284 3679489 4538773 5216621 5645660
7 7443563 5181142 8804416 8726696 5358847 7155276 4433125
7 2230555 3920370 7851992 1176871 610460 309961 3921536
7 8518829 8639441 3373630 5036651 5291213 2308694 7477960
7 7178097 249343 9504976 8684596 6226627 1055259 4880436


k=3
m=1000
matrix=[['2', '5', '4'], ['3', '7', '8', '9'], ['5', '5', '7', '8', '9', '10']]


# Convert matrix elements to integer
matrix_int = [[int(i) for i in sublist] for sublist in matrix]
sum=0
for index, item in enumerate(matrix_int):
    sum = sum + int(max(item))**2
print(int(sum) % int(m))


# print(int(max(i))**2)
# print(list(filter(i, lambda: x : max(int(x)) )))
# Out:
# 9
# [2, 5, 4]
# 5
# [3, 7, 8, 9]
# 9
# [5, 5, 7, 8, 9, 10]
# 10
# 206

# %%
matrix_str = """7 6429964 4173738 9941618 2744666 5392018 5813128 9452095
7 6517823 4135421 6418713 9924958 9370532 7940650 2027017
7 1506500 3460933 1550284 3679489 4538773 5216621 5645660
7 7443563 5181142 8804416 8726696 5358847 7155276 4433125
7 2230555 3920370 7851992 1176871 610460 309961 3921536
7 8518829 8639441 3373630 5036651 5291213 2308694 7477960
7 7178097 249343 9504976 8684596 6226627 1055259 4880436"""

m=867
m0=998
matrix_str0 = """6 67828645 425092764 242723908 669696211 501122842 438815206
4 625649397 295060482 262686951 815352670
3 100876777 196900030 523615865"""

matrix_int = [list(map(int, row.split())) for row in matrix_str.split('\n')]
# Convert matrix elements to integer
# matrix_int = [[int(i) for i in sublist] for sublist in matrix]
sum1=0
for index, item in enumerate(matrix_int):
    print(item, max(item)**2) 
    sum1 = sum1 + pow(max(item), 2) 

print(sum1)
print(sum1 % m)



# # Print the integer matrix
# for row in matrix:
#     print(row)
# Out:
# [7, 6429964, 4173738, 9941618, 2744666, 5392018, 5813128, 9452095] 98835768457924
# [7, 6517823, 4135421, 6418713, 9924958, 9370532, 7940650, 2027017] 98504791301764
# [7, 1506500, 3460933, 1550284, 3679489, 4538773, 5216621, 5645660] 31873476835600
# [7, 7443563, 5181142, 8804416, 8726696, 5358847, 7155276, 4433125] 77517741101056
# [7, 2230555, 3920370, 7851992, 1176871, 610460, 309961, 3921536] 61653778368064
# [7, 8518829, 8639441, 3373630, 5036651, 5291213, 2308694, 7477960] 74639940792481
# [7, 7178097, 249343, 9504976, 8684596, 6226627, 1055259, 4880436] 90344568760576
# 533370065617465
# 31

# %%
data = [9941618, 9924958, 5645660, 8804416, 7851992, 8639441, 9504976]
# Calculate the sum of the squares of the elements in the data list
sum_of_squares = sum(x**2 for x in data)

# Calculate the result of the sum of squares modulo 867
result2 = sum_of_squares % 867
print(result2)

# Calculate the sum of the data
total=0
for item in data:
    total = total + pow(item, 2, m) 
    
print(total)

# Calculate (sum**2 % 861)
result = total % 867

print(total)
print(result)

# data = [9941618, 9924958, 5645660, 8804416, 7851992, 8639441, 9504976]
# (9941618**2 + 9924958**2 + 5645660**2 + 8804416**2 + 7851992**2 + 8639441**2 + 9504976**2) % 867=?
# Out:
# 31
# 3499
# 3499
# 31

# %%
# Define the list of lists
data = [
    [7, 6429964, 4173738, 9941618, 2744666, 5392018, 5813128, 9452095],
    [7, 6517823, 4135421, 6418713, 9924958, 9370532, 7940650, 2027017],
    [7, 1506500, 3460933, 1550284, 3679489, 4538773, 5216621, 5645660],
    [7, 7443563, 5181142, 8804416, 8726696, 5358847, 7155276, 4433125],
    [7, 2230555, 3920370, 7851992, 1176871, 610460, 309961, 3921536],
    [7, 8518829, 8639441, 3373630, 5036651, 5291213, 2308694, 7477960],
    [7, 7178097, 249343, 9504976, 8684596, 6226627, 1055259, 4880436]
]

# Find the maximum value for each sublist
max_values = [max(sublist) for sublist in data]

print(max_values)
# Out:
# [9941618, 9924958, 5645660, 8804416, 7851992, 8639441, 9504976]

# %%
matrix = [
    [6, 67828645, 425092764, 242723908, 669696211, 501122842, 438815206],
    [4, 625649397, 295060482, 262686951, 815352670],
    [3, 100876777, 196900030, 523615865]
]

m = 998
sum1=0
for index, item in enumerate(matrix):
    print(item, max(item)**2) 
    sum1 = sum1 + max(item)**2

print(sum1)
print(sum1 % m)



# Function to calculate the result
def calculate_result(matrix, m):
    result = 0
    for row in matrix:
        max_item_row = max(row)
        result += (max_item_row ** 2) % m
    return result % m

# Calculate and print the result
result = calculate_result(matrix, m)
print(result)
# Out:
# [6, 67828645, 425092764, 242723908, 669696211, 501122842, 438815206] 448493015027756521
# [4, 625649397, 295060482, 262686951, 815352670] 664799976476128900
# [3, 100876777, 196900030, 523615865] 274173574079698225
# 1387466565583583646
# 624
# 624

# %%
# matrix = ['Tsi', 'h%x', 'i #', 'sM ', '$a ', '#t%', 'ir!']
matrix = ['# i#',' @#U']

#This$#is% Matrix#  %!
#This is Matrix#  %!

#!/bin/python3
import math
import os
import random
import re
import sys
result =[]
# alpha = ['T', 't', 'h','H','i','I', 'S', 's', 'M','a','r','x','A','R','X' ]
# matrix = ['Tsi', 'h%x', 'i #', 'sM ', '$a ', '#t%', 'ir!']

alpha = ''
space = 0
sign = 0
result = ''
space_sign=''
res_aplha = []
res_sign = []
alphalist = []
res_aplha2 = []
res_sign2 = []

transposed_array = [[row[i] for row in matrix] for i in range(len(matrix[0]))]
for index, str in enumerate(transposed_array):
    for substr in str:   
        result = result + substr
        
for index, substr in enumerate(result):
        while substr.isalpha():
             alpha = alpha + substr             
             break        
        while not substr.isalpha():            
            while len(alpha)>=1:
                res_aplha.append(alpha)
                break
            havealpha = True
            checkalpha = False
            for s in result[index+1:]:                
                while s.isalpha():
                    checkalpha = True
                    break
            while not checkalpha:
                space_sign = space_sign + substr 
                res_aplha2.append(substr)
                break            
            alpha = ''
            break   
            
strEnd = ''
for item in res_aplha:
    while len(item) > 1:
        strEnd = strEnd+' '+item
        break
       
print(strEnd+space_sign)

# %%
################################################################this s final okay
matrix1 = ['Tsi', 'h%x', 'i #', 'sM ', '$a ', '#t%', 'ir!']
matrix0 = ['# i#',' @#U']
matrix = ['# ',' @']

#  @i U
#This is Matrix#  %!
#!/bin/python3
import math
import os
import random
import re
import sys
# alpha = ['T', 't', 'h','H','i','I', 'S', 's', 'M','a','r','x','A','R','X' ]

alpha = ''
sign = 0
result = ''
space_sign_start=''
space_sign_end=''
res_aplpha = []
res_aplpha2 = []


transposed_array = [[row[i] for row in matrix] for i in range(len(matrix[0]))]
transposed_array0 = [[row[i] for row in matrix0] for i in range(len(matrix0[0]))]
# print(transposed_array0)
print(transposed_array)

#matrix = [
#          '# i#'
#          ' @#U'
#]
#R=#  @i U
#R=This is Matrix#  %!
#result:#  @i##U

for index, str in enumerate(transposed_array):
    for substr in str:  
        while substr.isalpha():
             alpha = alpha + substr             
             break
        while not substr.isspace() and not substr.isalpha():
            sign = sign + 1
            break
        while not substr.isspace() and not substr.isalpha() and sign > 1:
            sign = sign - 1
            alpha = alpha + ' '
            break
        while not substr.isalpha() and len(alpha)<=1:            
            space_sign_start = space_sign_start + substr 
            break

for index, str in enumerate(transposed_array):
    for substr in str:   
        result = result + substr       
alpha1 = ''  
for index, substr in enumerate(result):
        while substr.isalpha():
             alpha1 = alpha1 + substr             
             break        
        while not substr.isalpha():            
            res_aplpha.append(alpha)
            havealpha = True
            checkalpha = False
            for s in result[index+1:]:                
                while s.isalpha():
                    checkalpha = True
                    break
            while not checkalpha:
                space_sign_end = space_sign_end + substr 
                res_aplpha2.append(substr)
                break            
            alpha1 = ''
            break   

print(f"alpha:{alpha.strip()}")
while alpha.strip():
    print(space_sign_start + alpha.strip() + space_sign_end)           
    break
    
while space_sign_start == space_sign_end:
    print(space_sign_start)           
    break


#matrix = [
#          '# i#'
#          ' @#U'
#]

#R=#  @
#R=#  @i U
#R=This is Matrix#  %!
# Out:
# [['#', ' '], [' ', '@']]
# alpha:
# #  @

# %%
string = 'ABCDEFGHIJKLIMNOQRSTUVWXYZ'
i = 4

# print(string[4:4])
# print(string[8:4])
# print(string[12:4])
# print(string[16:4])
# print(string[20:4])
# print(string[24:4])

    # print(index, item)
    # print(string[:index])
    # print(f"index:{index}, i:{i}, result:{index % i}")
    # # print(string[index:i])

for index , item in enumerate(string):    
    if index % i == 0:
        print(string[index:i+index])
# Out:
# ABCD
# EFGH
# IJKL
# IMNO
# QRST
# UVWX
# YZ

# %%
import textwrap

def wrap(string, max_width):
    result = ''
    for index , item in enumerate(string):    
        if index % max_width == 0:
            # print(string[index:max_width+index])
            result = result + string[index:max_width+index] + '\n'
            
    return result

string, max_width = 'bscnksbcjscksbcjksbckjdscsbdcbsdkjbcsdjcbsdjkcbsdkjbckjdsbjksd',9  #'ABCDEFGHIJKLIMNOQRSTUVWXYZ', 4
result = wrap(string, max_width)
# print('result')
print(result)
# Out:
# bscnksbcj
# scksbcjks
# bckjdscsb
# dcbsdkjbc
# sdjcbsdjk
# cbsdkjbck
# jdsbjksd
